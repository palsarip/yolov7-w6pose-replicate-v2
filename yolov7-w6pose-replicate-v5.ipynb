# %%
import cv2
import time
import torch
import numpy as np
import os
import math
from collections import deque
from utils.datasets import letterbox
from utils.torch_utils import select_device
from models.experimental import attempt_load
from utils.plots import output_to_keypoint, plot_skeleton_kpts
from utils.general import non_max_suppression_kpt, strip_optimizer
from torchvision import transforms

class FallDetector:
    def __init__(self, poseweights='yolov7-w6-pose.pt', device='0'):
        """
        Initialize the Fall Detector with parameters as defined in the paper
        "Enhanced Fall Detection Using YOLOv7-W6-Pose for Real-Time Elderly Monitoring"
        
        Key parameters:
        - LENGTH_FACTOR_ALPHA (α): Used in height condition formula (Section 3.1)
        - VELOCITY_THRESHOLD: Threshold for fall speed detection (Section 3.2)
        - LEG_ANGLE_THRESHOLD: Degrees threshold for leg angles (Section 3.2)
        - TORSO_ANGLE_THRESHOLD: Degrees threshold for torso orientation (Section 3.2)
        - ASPECT_RATIO_THRESHOLD: Width/height ratio threshold (Section 3.1)
        - CONFIDENCE_THRESHOLD: Minimum keypoint confidence for reliable detection
        """
        print(f"Initializing Fall Detector with weights: {poseweights} on device: {device}")
        
        # Select the appropriate device
        self.device = select_device(device)
        self.half = self.device.type != 'cpu'
        
        # Load model
        self.model = attempt_load(poseweights, map_location=self.device)
        self.model.eval()
        
        # Create output directory if it doesn't exist
        os.makedirs('output', exist_ok=True)
        
        # Threshold parameters as defined in the paper
        self.LENGTH_FACTOR_ALPHA = 0.5  # α in the height condition formula
        self.VELOCITY_THRESHOLD = 1.0    # px/frame for fall speed
        self.LEG_ANGLE_THRESHOLD = 45    # degrees for leg angles
        self.TORSO_ANGLE_THRESHOLD = 50  # degrees for torso orientation
        self.ASPECT_RATIO_THRESHOLD = 0.8 # width/height ratio
        self.CONFIDENCE_THRESHOLD = 0.4  # minimum keypoint confidence
        self.TARGET_FPS = 25
        
        # State tracking variables
        self.prev_keypoints = None
        self.velocity_buffer = deque(maxlen=3)  # tracks vertical speed
        self.fall_buffer = deque(maxlen=2)      # confirmation buffer
        self.prev_frame_time = None
        self.fall_start_time = None
        self.prev_shoulder_y = None
        
        # Fall detection status
        self.fall_detected = False
    
    def calculate_euclidean_distance(self, point1, point2):
        """
        Calculate Euclidean distance between two points
        Used in the paper to measure distances between key body points,
        particularly for the Lfactor (length factor) calculation in Section 3.1
        
        Args:
            point1, point2: Coordinate points (x,y)
        Returns:
            Euclidean distance between the points
        """
        return math.hypot(point1[0]-point2[0], point1[1]-point2[1])

    def calculate_angle(self, a, b, c):
        """
        Calculate angle between three points (in degrees)
        Used in the paper for calculating leg angles (Section 3.2)
        
        Args:
            a, b, c: Three points where b is the vertex
        Returns:
            Angle in degrees
        """
        try:
            ba = np.array([a[0]-b[0], a[1]-b[1]])
            bc = np.array([c[0]-b[0], c[1]-b[1]])
            cosine_angle = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc) + 1e-6)
            return np.degrees(np.arccos(np.clip(cosine_angle, -1.0, 1.0)))
        except:
            return 180  # return maximum angle if calculation fails

    def calculate_torso_angle(self, shoulders, hips):
        """
        Calculate torso angle relative to vertical axis
        Implements the torso orientation assessment described in Section 3.2
        of the paper to detect when the torso is horizontal (fallen state)
        
        Args:
            shoulders: list of shoulder points [(x,y), (x,y)]
            hips: list of hip points [(x,y), (x,y)]
        Returns:
            angle in degrees between torso and vertical axis
        """
        shoulder_center = np.mean(shoulders, axis=0)
        hip_center = np.mean(hips, axis=0)
        vertical_vector = np.array([0, 1])
        torso_vector = np.array([hip_center[0]-shoulder_center[0], 
                                hip_center[1]-shoulder_center[1]])
        
        if np.linalg.norm(torso_vector) < 1e-6:
            return 90  # neutral angle if points overlap
            
        cosine = np.dot(torso_vector, vertical_vector) / (np.linalg.norm(torso_vector) + 1e-6)
        return np.degrees(np.arccos(np.clip(cosine, -1.0, 1.0)))

    def detect_fall(self, keypoints):
        """
        Main fall detection function implementing the paper's algorithm from Sections 3.1 and 3.2
        Combines multiple conditions (height, velocity, angles, aspect ratio) to detect falls
        
        Args:
            keypoints: Array of 17 keypoints with (x,y,confidence)
        Returns:
            tuple: (is_fall, state, condition_info)
        """
        # Keypoint indices as defined in the paper
        NOSE = 0
        LEFT_SHOULDER = 5
        RIGHT_SHOULDER = 6
        LEFT_HIP = 11
        RIGHT_HIP = 12
        LEFT_KNEE = 13
        RIGHT_KNEE = 14
        LEFT_ANKLE = 15
        RIGHT_ANKLE = 16
        
        try:
            # Extract keypoints with confidence check
            kp = {}
            
            # Reshape keypoints to get (x, y, conf) format for each keypoint
            reshaped_kpts = keypoints.reshape(-1, 3)
            
            # Extract specific keypoints
            kp['nose'] = reshaped_kpts[NOSE]
            kp['left_shoulder'] = reshaped_kpts[LEFT_SHOULDER]
            kp['right_shoulder'] = reshaped_kpts[RIGHT_SHOULDER]
            kp['left_hip'] = reshaped_kpts[LEFT_HIP]
            kp['right_hip'] = reshaped_kpts[RIGHT_HIP]
            kp['left_knee'] = reshaped_kpts[LEFT_KNEE]
            kp['right_knee'] = reshaped_kpts[RIGHT_KNEE]
            kp['left_ankle'] = reshaped_kpts[LEFT_ANKLE]
            kp['right_ankle'] = reshaped_kpts[RIGHT_ANKLE]
            
            # Confidence check for all keypoints
            if any(point[2] < self.CONFIDENCE_THRESHOLD for point in kp.values()):
                return False, "low_confidence", []

            # Get coordinates (convert to tuples for clarity)
            ls = (kp['left_shoulder'][0], kp['left_shoulder'][1])
            rs = (kp['right_shoulder'][0], kp['right_shoulder'][1])
            lh = (kp['left_hip'][0], kp['left_hip'][1])
            rh = (kp['right_hip'][0], kp['right_hip'][1])
            lk = (kp['left_knee'][0], kp['left_knee'][1])
            rk = (kp['right_knee'][0], kp['right_knee'][1])
            la = (kp['left_ankle'][0], kp['left_ankle'][1])
            ra = (kp['right_ankle'][0], kp['right_ankle'][1])

            """ 1. HEIGHT CONDITION (Paper Section 3.1) """
            # Calculate length factor (Lfactor) as Euclidean distance
            torso_mid = ((lh[0] + rh[0])/2, (lh[1] + rh[1])/2)
            Lfactor = self.calculate_euclidean_distance(ls, torso_mid)
            
            # Get vertical positions
            max_feet_y = max(la[1], ra[1])
            min_shoulder_y = min(ls[1], rs[1])
            
            # Paper's height condition: yl ≤ yFl + α·Lfactor
            height_cond = min_shoulder_y >= (max_feet_y - self.LENGTH_FACTOR_ALPHA * Lfactor)
            
            """ 2. VELOCITY CONDITION (Paper Section 3.2) """
            current_time = time.time()
            vertical_speed = 0
            current_min_y = min(ls[1], rs[1])
            
            if self.prev_shoulder_y is not None and self.prev_frame_time is not None:
                time_elapsed = current_time - self.prev_frame_time
                if time_elapsed > 0:
                    vertical_speed = (current_min_y - self.prev_shoulder_y) / time_elapsed
                    self.velocity_buffer.append(abs(vertical_speed))
            
            avg_speed = sum(self.velocity_buffer)/len(self.velocity_buffer) if self.velocity_buffer else 0
            speed_cond = avg_speed >= self.VELOCITY_THRESHOLD
            
            """ 3. ANGLE CONDITIONS (Paper Section 3.2) """
            left_leg_angle = self.calculate_angle(lh, lk, la)
            right_leg_angle = self.calculate_angle(rh, rk, ra)
            leg_angle_cond = min(left_leg_angle, right_leg_angle) < self.LEG_ANGLE_THRESHOLD
            
            # Torso orientation (not explicitly in paper but mentioned in text)
            torso_angle = self.calculate_torso_angle([ls, rs], [lh, rh])
            torso_cond = torso_angle > self.TORSO_ANGLE_THRESHOLD
            
            """ 4. ASPECT RATIO CONDITION (Paper Section 3.1) """
            # Body orientation ratio: width/height
            body_width = abs(ls[0] - rs[0])
            head_to_feet = abs(kp['nose'][1] - max_feet_y)
            orientation_ratio = body_width / (head_to_feet + 1e-6)
            aspect_cond = orientation_ratio > self.ASPECT_RATIO_THRESHOLD
            
            """ FALL DECISION LOGIC (Paper Section 3) """
            # Combined conditions - at least 2 must be true
            conditions_met = sum([height_cond, speed_cond, leg_angle_cond, torso_cond, aspect_cond])
            
            # State determination
            current_state = "normal"
            conditions_info = []
            
            if height_cond:
                if speed_cond:  # Rapid descent
                    current_state = "falling"
                    self.fall_start_time = current_time
                    conditions_info.append(f"speed:{avg_speed:.1f}px/s")
                elif torso_cond and self.fall_start_time and (current_time - self.fall_start_time < 1.0):
                    current_state = "fallen"
                    conditions_info.append("horizontal")
            
            if leg_angle_cond:
                conditions_info.append(f"leg_angle:{min(left_leg_angle, right_leg_angle):.0f}°")
            
            if aspect_cond:
                conditions_info.append(f"aspect:{orientation_ratio:.2f}")
            
            # Final decision with confirmation buffer
            is_fall = conditions_met >= 2
            self.fall_buffer.append(is_fall)
            final_detection = sum(self.fall_buffer) >= 2 if len(self.fall_buffer) >= 1 else is_fall
            
            if final_detection:
                current_state = "fallen"
                self.fall_detected = True
            else:
                self.fall_detected = False
            
            # Update tracking variables
            self.prev_keypoints = kp
            self.prev_shoulder_y = current_min_y
            self.prev_frame_time = current_time
            
            # Diagnostic information
            conditions_info.extend([
                f"height:{'Y' if height_cond else 'N'}",
                f"speed:{'Y' if speed_cond else 'N'}",
                f"leg_angle:{'Y' if leg_angle_cond else 'N'}",
                f"torso:{'Y' if torso_cond else 'N'}",
                f"aspect:{'Y' if aspect_cond else 'N'}",
                f"conf:{min(p[2] for p in kp.values()):.2f}"
            ])
            
            return final_detection, current_state, conditions_info
            
        except Exception as e:
            print(f"Detection error: {str(e)}")
            return False, "error", [f"Error: {str(e)}"]

    def process_frame(self, frame):
        """
        Process a single frame for fall detection
        
        Args:
            frame: Video frame to process
            
        Returns:
            frame: Processed frame with detections
            is_fall: Boolean indicating whether a fall was detected
            state: Current state (normal, falling, fallen)
            condition_info: List of conditions that triggered the detection
        """
        # Preprocess image
        orig_image = frame.copy()
        image = cv2.cvtColor(orig_image, cv2.COLOR_BGR2RGB)
        
        # Resize image while maintaining aspect ratio
        frame_height, frame_width = orig_image.shape[:2]
        image = letterbox(image, (frame_width), stride=64, auto=True)[0]
        
        # Convert to tensor
        image_ = image.copy()
        image = transforms.ToTensor()(image)
        image = torch.tensor(np.array([image.numpy()]))
        
        image = image.to(self.device)
        image = image.float()
        
        # Inference
        with torch.no_grad():
            output, _ = self.model(image)
            
        # Post-process
        output = non_max_suppression_kpt(output, 0.25, 0.65, nc=self.model.yaml['nc'], nkpt=self.model.yaml['nkpt'], kpt_label=True)
        output = output_to_keypoint(output)
        
        # Convert back to BGR for display
        img = image[0].permute(1, 2, 0) * 255
        img = img.cpu().numpy().astype(np.uint8)
        img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
        
        # Initialize fall status and state for this frame
        is_fall = False
        current_state = "normal"
        condition_info = []
        
        # Process each person detected
        for idx in range(output.shape[0]):
            # Draw skeleton and keypoints
            plot_skeleton_kpts(img, output[idx, 7:].T, 3)
            
            # Calculate improved bounding box based on keypoints (YouTube approach)
            # Find the minimum and maximum x,y coordinates from all keypoints
            kpts = output[idx, 7:].reshape(-1, 3)
            
            # Initialize with first keypoint
            x_values = [kpt[0] for kpt in kpts if kpt[2] > 0.5]  # Only use keypoints with confidence > 0.5
            y_values = [kpt[1] for kpt in kpts if kpt[2] > 0.5]
            
            if x_values and y_values:  # Check if we have valid keypoints
                xmin, ymin = min(x_values), min(y_values)
                xmax, ymax = max(x_values), max(y_values)
                
                # Add padding to make bounding box a bit larger
                padding = 10
                xmin = max(0, xmin - padding)
                ymin = max(0, ymin - padding)
                xmax = xmax + padding
                ymax = ymax + padding
                
                # Calculate aspect ratio for reference (not used in detection)
                width = xmax - xmin
                height = ymax - ymin
                bbox_aspect_ratio = width / height if height > 0 else 0
                
                # Calculate center
                cx = int((xmin + xmax) // 2)
                cy = int((ymin + ymax) // 2)
                
                # For debugging: show aspect ratio on frame
                cv2.putText(img, f"Ratio: {bbox_aspect_ratio:.2f}", (10, 30), 
                           cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)
            else:
                # Fallback to original bounding box if no valid keypoints
                x1, y1, x2, y2 = output[idx, 0], output[idx, 1], output[idx, 2], output[idx, 3]
                xmin, ymin = x1, y1
                xmax, ymax = x2, y2
                cx, cy = int((x1 + x2) // 2), int((y1 + y2) // 2)
            
            # Get key points for this person
            key_points = output[idx, 7:]
            
            # Detect fall for this person using enhanced algorithm
            person_fall, person_state, person_conditions = self.detect_fall(key_points)
            
            # If any person is falling, set global fall status
            if person_fall:
                is_fall = True
                current_state = person_state
                condition_info = person_conditions
                
                # Add visual indication of fall
                status_text = f"FALL DETECTED: {person_state.upper()}"
                cv2.putText(img, status_text, (50, 50), 
                           cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
                
                # Draw the bounding box in red for a fall
                cv2.rectangle(img, (int(xmin), int(ymin)), (int(xmax), int(ymax)), (0, 0, 255), 2)
                
                # For YouTube-style visual, add a colored rectangle at the center
                cv2.rectangle(img, (cx-10, cy-10), (cx+10, cy+10), (84, 61, 247), -1)
                
                # Add condition info to the frame
                for i, cond in enumerate(person_conditions[:3]):  # Show first 3 conditions only
                    cv2.putText(img, cond, (10, 60 + i*25), 
                              cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 255), 1)
            else:
                # Draw normal bounding box in green for no fall
                cv2.rectangle(img, (int(xmin), int(ymin)), (int(xmax), int(ymax)), (0, 255, 0), 1)
                
                # Show normal state
                cv2.putText(img, f"State: {person_state}", (10, 60), 
                          cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 1)
        
        return img, is_fall, current_state, condition_info

def run_fall_detection(poseweights='yolov7-w6-pose.pt', source='pose.mp4', device='cpu', display=True, save_output=True):
    """
    Run fall detection on a video or webcam feed
    
    Args:
        poseweights: Path to the YOLOv7 pose weights
        source: Path to video file or webcam ID (0, 1, etc.)
        device: Device to run inference on ('cpu' or '0', '1', etc. for GPU)
        display: Whether to show video with detections in real-time
        save_output: Whether to save the output video
    """
    # Initialize the fall detector
    detector = FallDetector(poseweights=poseweights, device=device)
    
    # Parse the input source
    input_path = source
    if source.isnumeric():
        input_path = int(source)
    
    # Open video capture
    cap = cv2.VideoCapture(input_path)
    if not cap.isOpened():
        print(f"Error: Could not open video source {source}")
        return
    
    # Get video properties
    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = cap.get(cv2.CAP_PROP_FPS)
    
    # Setup output video writer if requested
    out = None
    if save_output:
        if isinstance(input_path, int):
            # For webcam
            output_path = os.path.join('output', f"webcam_fall_detection.mp4")
        else:
            # For video file
            filename = os.path.basename(input_path).split('.')[0]
            output_path = os.path.join('output', f"{filename}_fall_detection.mp4")
        
        # Create VideoWriter
        fourcc = cv2.VideoWriter_fourcc(*'mp4v')
        out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))
        print(f"Output will be saved to: {output_path}")
    
    # Process video frames
    frame_count = 0
    total_fps = 0
    
    print("Starting fall detection...")
    
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        
        frame_count += 1
        print(f"Processing frame {frame_count}")
        
        # Process frame for fall detection
        start_time = time.time()
        processed_frame, is_fall, current_state, condition_info = detector.process_frame(frame)
        end_time = time.time()
        
        # Calculate FPS
        processing_fps = 1 / (end_time - start_time)
        total_fps += processing_fps
        
        # Resize processed frame to match original dimensions for display and saving
        processed_frame_resized = cv2.resize(processed_frame, (frame_width, frame_height))
        
        # Add FPS info
        cv2.putText(processed_frame_resized, f"FPS: {processing_fps:.2f}", (frame_width - 150, 30), 
                   cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
        
        # Display the frame if requested
        if display:
            cv2.imshow('Fall Detection', processed_frame_resized)
            
            # Exit on 'q' press
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break
        
        # Save frame to output video if requested
        if save_output and out is not None:
            out.write(processed_frame_resized)
    
    # Release resources
    cap.release()
    if save_output and out is not None:
        out.release()
    cv2.destroyAllWindows()
    
    # Print statistics
    if frame_count > 0:
        avg_fps = total_fps / frame_count
        print(f"Processed {frame_count} frames")
        print(f"Average FPS: {avg_fps:.2f}")
        if save_output:
            print(f"Output saved to: {output_path}")

def process_dataset_folder(dataset_path, detector, is_sorted=False):
    """
    Process the Le2i fall detection dataset with the hierarchical folder structure
    
    Args:
        dataset_path: Path to the dataset root directory
        detector: Initialized FallDetector instance
        is_sorted: Boolean indicating if the dataset is in sorted structure (Fall/Non Fall folders)
    """
    import os
    import cv2
    import time
    import numpy as np
    from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
    
    # Path to Le2i dataset
    le2i_path = os.path.join(dataset_path, "le2i")
    
    # Initialize tracking variables for performance metrics
    true_labels = []
    predicted_labels = []
    
    # Total counters for statistics
    total_videos = 0
    total_frames = 0
    processing_times = []
    
    print(f"Starting batch processing of Le2i dataset at {le2i_path}")
    
    if is_sorted:
        # Process the sorted structure (Fall/Non Fall folders)
        fall_folder = os.path.join(le2i_path, "Le2i_Sorted", "Fall")
        nonfall_folder = os.path.join(le2i_path, "Le2i_Sorted", "Non Fall")  # Corrected folder name with space
        
        # Check if Fall folder exists
        if os.path.exists(fall_folder):
            print(f"Processing Fall folder: {fall_folder}")
            
            # Get all environment subfolders
            env_folders = [d for d in os.listdir(fall_folder) if os.path.isdir(os.path.join(fall_folder, d))]
            print(f"Found {len(env_folders)} environment folders in Fall folder: {', '.join(env_folders)}")
            
            # Process each environment folder
            for env_folder in env_folders:
                env_path = os.path.join(fall_folder, env_folder)
                videos_folder = os.path.join(env_path, "Videos")
                
                if os.path.exists(videos_folder):
                    print(f"Processing videos in {env_folder}/Videos")
                    
                    # Get all video files
                    video_files = [f for f in os.listdir(videos_folder) 
                                  if f.endswith(('.mp4', '.avi', '.mov', '.mkv', '.MP4', '.AVI', '.MOV', '.MKV'))]
                    
                    print(f"Found {len(video_files)} video files in {env_folder}/Videos")
                    
                    for video_file in video_files:
                        video_path = os.path.join(videos_folder, video_file)
                        print(f"Processing fall video: {env_folder}/{video_file}")
                        
                        # Extract true labels (1 for fall)
                        true_label = 1
                        
                        try:
                            # Process the video and get predictions
                            result, frames_processed, avg_time = process_single_video(video_path, detector, true_label)
                            
                            # Extend the lists with results
                            true_labels.extend([true_label] * len(result))
                            predicted_labels.extend(result)
                            
                            # Update statistics
                            total_videos += 1
                            total_frames += frames_processed
                            processing_times.append(avg_time)
                        except Exception as e:
                            print(f"Error processing video {video_file}: {str(e)}")
                else:
                    print(f"Videos folder not found in {env_folder}")
        else:
            print(f"Fall folder not found at {fall_folder}")
        
        # Check if NonFall folder exists
        if os.path.exists(nonfall_folder):
            print(f"Processing Non Fall folder: {nonfall_folder}")
            
            # Get all environment subfolders
            env_folders = [d for d in os.listdir(nonfall_folder) if os.path.isdir(os.path.join(nonfall_folder, d))]
            print(f"Found {len(env_folders)} environment folders in Non Fall folder: {', '.join(env_folders)}")
            
            # Process each environment folder
            for env_folder in env_folders:
                env_path = os.path.join(nonfall_folder, env_folder)
                videos_folder = os.path.join(env_path, "Videos")
                
                if os.path.exists(videos_folder):
                    print(f"Processing videos in {env_folder}/Videos")
                    
                    # Get all video files
                    video_files = [f for f in os.listdir(videos_folder) 
                                  if f.endswith(('.mp4', '.avi', '.mov', '.mkv', '.MP4', '.AVI', '.MOV', '.MKV'))]
                    
                    print(f"Found {len(video_files)} video files in {env_folder}/Videos")
                    
                    for video_file in video_files:
                        video_path = os.path.join(videos_folder, video_file)
                        print(f"Processing non-fall video: {env_folder}/{video_file}")
                        
                        # Extract true labels (0 for non-fall)
                        true_label = 0
                        
                        try:
                            # Process the video and get predictions
                            result, frames_processed, avg_time = process_single_video(video_path, detector, true_label)
                            
                            # Extend the lists with results
                            true_labels.extend([true_label] * len(result))
                            predicted_labels.extend(result)
                            
                            # Update statistics
                            total_videos += 1
                            total_frames += frames_processed
                            processing_times.append(avg_time)
                        except Exception as e:
                            print(f"Error processing video {video_file}: {str(e)}")
                else:
                    print(f"Videos folder not found in {env_folder}")
        else:
            print(f"Non Fall folder not found at {nonfall_folder}")
    else:
        # Process the traditional structure with mixed videos and ground truth files
        videos_folder = os.path.join(le2i_path, "Videos")
        
        # Check if directory exists
        if not os.path.exists(videos_folder):
            print(f"Error: Videos directory not found at {videos_folder}")
            return
            
        # List of environments in Le2i dataset
        environments = ["Home", "Coffee_room", "Office", "Lecture_room"]
        
        for env in environments:
            env_folder = os.path.join(videos_folder, env)
            if os.path.exists(env_folder):
                print(f"Processing environment: {env}")
                
                # Get all video files
                video_files = [f for f in os.listdir(env_folder) if f.endswith(('.mp4', '.avi'))]
                
                for video_file in video_files:
                    video_path = os.path.join(env_folder, video_file)
                    print(f"Processing video: {video_file}")
                    
                    # Determine if this is a fall video based on filename
                    # In Le2i dataset, videos with 'fall' in the name are fall videos
                    true_label = 1 if 'fall' in video_file.lower() else 0
                    
                    # Process the video and get predictions
                    result, frames_processed, avg_time = process_single_video(video_path, detector, true_label)
                    
                    # Extend the lists with results
                    true_labels.extend([true_label] * len(result))
                    predicted_labels.extend(result)
                    
                    # Update statistics
                    total_videos += 1
                    total_frames += frames_processed
                    processing_times.append(avg_time)
    
    # Calculate and display performance metrics based on paper's key metrics
    if true_labels and predicted_labels:
        calculate_and_display_metrics(true_labels, predicted_labels)
    
    # Display overall processing statistics
    print("\nProcessing Statistics:")
    print(f"Total videos processed: {total_videos}")
    print(f"Total frames processed: {total_frames}")
    if processing_times:
        avg_processing_time = sum(processing_times) / len(processing_times)
        print(f"Average processing time per frame: {avg_processing_time:.4f} seconds")
        print(f"Average FPS: {1/avg_processing_time:.2f}")


def process_single_video(video_path, detector, true_label):
    """
    Process a single video file and return predictions
    
    Args:
        video_path: Path to the video file
        detector: Initialized FallDetector instance
        true_label: Ground truth label (1 for fall, 0 for non-fall)
        
    Returns:
        predictions: List of predicted labels for each frame
        frames_processed: Number of frames processed
        avg_processing_time: Average processing time per frame
    """
    import cv2
    import time
    import numpy as np
    import os
    
    print(f"Opening video file: {video_path}")
    # Verify the file exists
    if not os.path.exists(video_path):
        print(f"Error: Video file does not exist: {video_path}")
        return [0], 0, 0
    
    # Open video
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"Error: Could not open video {video_path}")
        print(f"Video file exists: {os.path.exists(video_path)}")
        print(f"Video file size: {os.path.getsize(video_path) if os.path.exists(video_path) else 'N/A'} bytes")
        return [0], 0, 0
    
    # Get video properties for debugging
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = cap.get(cv2.CAP_PROP_FPS)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    
    print(f"Video properties: {width}x{height}, {fps} FPS, {total_frames} frames")
    
    # Initialize counters and results
    frames_processed = 0
    predictions = []
    processing_times = []
    
    # Process each frame
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
            
        frames_processed += 1
        
        # Process frame for fall detection
        start_time = time.time()
        try:
            processed_frame, is_fall, current_state, condition_info = detector.process_frame(frame)
            end_time = time.time()
            
            processing_time = end_time - start_time
            processing_times.append(processing_time)
            
            # Record prediction (1 for fall, 0 for non-fall)
            predictions.append(1 if is_fall else 0)
        except Exception as e:
            print(f"Error processing frame {frames_processed}: {str(e)}")
            predictions.append(0)  # Default to no fall on error
        
        # Show progress every 5 frames
        if frames_processed % 5 == 0:
            print(f"Processed {frames_processed}/{total_frames} frames from {os.path.basename(video_path)}")
    
    # Release video capture
    cap.release()
    
    # Check if we processed any frames
    if not processing_times:
        print("No frames were successfully processed.")
        return [0], 0, 0
    
    # Calculate average processing time
    avg_processing_time = sum(processing_times) / len(processing_times)
    
    # Handle predictions - use majority voting to determine overall video prediction
    # For fall videos (true_label = 1), even a single fall detection is considered a fall
    # For non-fall videos (true_label = 0), even a single false fall detection is considered a false positive
    if true_label == 1:  
        video_prediction = 1 if 1 in predictions else 0
    else:  
        video_prediction = 1 if 1 in predictions else 0
    
    print(f"Video prediction: {video_prediction} (True label: {true_label})")
    print(f"Processed {frames_processed} frames with avg processing time: {avg_processing_time:.4f} seconds")
    
    return [video_prediction], frames_processed, avg_processing_time


def calculate_and_display_metrics(true_labels, predicted_labels):
    """
    Calculate and display performance metrics based on the paper's key metrics
    
    Args:
        true_labels: List of ground truth labels
        predicted_labels: List of predicted labels
    """
    from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
    import numpy as np
    
    # Check if there are enough labels to calculate metrics
    if not true_labels or not predicted_labels:
        print("No data available to calculate metrics.")
        return
    
    if len(true_labels) != len(predicted_labels):
        print(f"Error: Mismatch in label lengths. True: {len(true_labels)}, Predicted: {len(predicted_labels)}")
        return
    
    # Calculate confusion matrix
    try:
        cm = confusion_matrix(true_labels, predicted_labels, labels=[0, 1])
        tn, fp, fn, tp = cm.ravel()
    except Exception as e:
        print(f"Error calculating confusion matrix: {str(e)}")
        return
    
    # Calculate metrics based on the paper
    accuracy = (tp + tn) / (tp + tn + fp + fn) if (tp + tn + fp + fn) > 0 else 0
    precision = tp / (tp + fp) if (tp + fp) > 0 else 0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
    
    # Display confusion matrix in a more readable format
    print("\nConfusion Matrix:")
    print(f"True Positives (TP): {tp}")
    print(f"True Negatives (TN): {tn}")
    print(f"False Positives (FP): {fp}")
    print(f"False Negatives (FN): {fn}")
    
    # Display metrics with percentage format matching the paper
    print("\nPerformance Metrics:")
    print(f"Accuracy: {accuracy:.2%}")
    print(f"Precision: {precision:.2%}")
    print(f"Recall (Sensitivity): {recall:.2%}")
    print(f"Specificity: {specificity:.2%}")
    print(f"F1 Score: {f1:.2%}")
    
    # Additional comparison with paper's metrics
    print("\nComparison with Paper's Metrics:")
    print("                  | Our Method | Paper's Method")
    print("------------------|------------|---------------")
    print(f"Accuracy          | {accuracy:.2%}     | 96.15%")
    print(f"Precision         | {precision:.2%}     | 97.00%")
    print(f"Recall            | {recall:.2%}     | 97.98%")
    print(f"Specificity       | {specificity:.2%}     | 90.32%")
    print(f"F1 Score          | {f1:.2%}     | 97.48%")
    
def run_interactive():
    """
    Interactive function to run fall detection with user input
    """
    # Get the weights file
    poseweights = input("Enter path to weights file [default: yolov7-w6-pose.pt]: ") or "yolov7-w6-pose.pt"
    
    # Get device type
    use_gpu = input("Use GPU? (y/n) [default: y]: ").lower() or "y"
    if use_gpu == "y":
        device = input("Enter GPU device ID [default: 0]: ") or "0"
    else:
        device = "cpu"
    
    # Get source type
    print("\nSelect input source:")
    print("1: Video file")
    print("2: Webcam")
    print("3: Batch process (Le2i dataset)")
    source_choice = input("Enter choice [1/2/3]: ")
    
    if source_choice == "1":
        # Video file
        default_video = "sample_video.mp4"
        source = input(f"Enter video file path [default: {default_video}]: ") or default_video
        # Ask if user wants to display the processed video in real-time
        display_video = input("Display video with pose estimation in real-time? (y/n) [default: y]: ").lower() or "y"
        # Ask if user wants to save the output video
        save_video = input("Save output video? (y/n) [default: y]: ").lower() or "y"
        
        print(f"\nRunning fall detection with:")
        print(f"- Weights: {poseweights}")
        print(f"- Device: {device}")
        print(f"- Source: {source}")
        print(f"- Display: {'Yes' if display_video == 'y' else 'No'}")
        print(f"- Save output: {'Yes' if save_video == 'y' else 'No'}")
        confirmation = input("\nConfirm? (y/n) [default: y]: ").lower() or "y"
        
        if confirmation == "y":
            # Run the model
            run_with_display = (display_video == "y")
            save_output = (save_video == "y")
            
            # First strip optimizer to ensure model works correctly
            strip_optimizer(device, poseweights)
            
            # Run fall detection
            run_fall_detection(
                poseweights=poseweights,
                source=source,
                device=device,
                display=run_with_display,
                save_output=save_output
            )
        else:
            print("Operation cancelled")
    
    elif source_choice == "2":
        # Webcam
        cam_id = input("Enter webcam ID [default: 0]: ") or "0"
        source = cam_id
        
        # Ask if user wants to save the output video
        save_video = input("Save output video? (y/n) [default: y]: ").lower() or "y"
        
        print(f"\nRunning fall detection with:")
        print(f"- Weights: {poseweights}")
        print(f"- Device: {device}")
        print(f"- Source: Webcam {source}")
        print(f"- Display: Yes")  # Always display for webcam
        print(f"- Save output: {'Yes' if save_video == 'y' else 'No'}")
        confirmation = input("\nConfirm? (y/n) [default: y]: ").lower() or "y"
        
        if confirmation == "y":
            # First strip optimizer to ensure model works correctly
            strip_optimizer(device, poseweights)
            
            # Run fall detection
            run_fall_detection(
                poseweights=poseweights,
                source=source,
                device=device,
                display=True,  # Always display for webcam
                save_output=(save_video == "y")
            )
        else:
            print("Operation cancelled")
    
    elif source_choice == "3":
        # Batch process (Le2i dataset)
        default_dataset_path = "datasets"
        dataset_path = input(f"Enter dataset root path [default: {default_dataset_path}]: ") or default_dataset_path
        
        # Check if the dataset path exists
        if not os.path.exists(dataset_path):
            print(f"Error: Dataset path '{dataset_path}' does not exist.")
            return
        
        # Check for Le2i dataset structure
        le2i_path = os.path.join(dataset_path, "le2i")
        if not os.path.exists(le2i_path):
            print(f"Error: Le2i dataset not found at {le2i_path}")
            return
        
        # Check for Le2i_Sorted structure
        le2i_sorted_path = os.path.join(le2i_path, "Le2i_Sorted")
        is_sorted = os.path.exists(le2i_sorted_path)
        
        if is_sorted:
            print(f"Found Le2i dataset with sorted structure (Fall/Non Fall folders)")
        else:
            print(f"Found Le2i dataset with traditional structure")
        
        print(f"\nRunning batch processing with:")
        print(f"- Weights: {poseweights}")
        print(f"- Device: {device}")
        print(f"- Dataset path: {le2i_path}")
        print(f"- Structure: {'Sorted' if is_sorted else 'Traditional'}")
        confirmation = input("\nConfirm? (y/n) [default: y]: ").lower() or "y"
        
        if confirmation == "y":
            # Initialize fall detector
            detector = FallDetector(poseweights=poseweights, device=device)
            
            # Process the entire dataset
            process_dataset_folder(dataset_path, detector, is_sorted)
        else:
            print("Operation cancelled")
    
    else:
        print("Invalid choice. Please run again and select a valid option.")

if __name__ == "__main__":
    # Run interactively
    run_interactive()
# Out:
# Enter path to weights file [default: yolov7-w6-pose.pt]:
# Use GPU? (y/n) [default: y]:
# Enter GPU device ID [default: 0]:
# Select input source:
# 1: Video file
# 2: Webcam
# 3: Batch process (Le2i dataset)
# Enter choice [1/2/3]:  3
# Enter dataset root path [default: datasets]:
# Found Le2i dataset with sorted structure (Fall/Non Fall folders)
#
# Running batch processing with:
# - Weights: yolov7-w6-pose.pt
# - Device: 0
# - Dataset path: datasets\le2i
# - Structure: Sorted
# Confirm? (y/n) [default: y]:  y
# Initializing Fall Detector with weights: yolov7-w6-pose.pt on device: 0
# F:\PROJECTS\Maching Learning & Artificial Intelligence\pose-estimation\models\experimental.py:242: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(w, map_location=map_location)  # load
# Fusing layers...
# C:\Users\naufa\anaconda3\envs\cv_env\Lib\site-packages\torch\functional.py:534: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\TensorShape.cpp:3596.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Starting batch processing of Le2i dataset at datasets\le2i
# Processing Fall folder: datasets\le2i\Le2i_Sorted\Fall
# Found 6 environment folders in Fall folder: Coffee_room_01, Coffee_room_02, Home_01, Home_02, Lecture_room, Office
# Processing videos in Coffee_room_01/Videos
# Found 48 video files in Coffee_room_01/Videos
# Processing fall video: Coffee_room_01/video (1).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (1).avi
# Video properties: 320x240, 25.0 FPS, 157 frames
# Processed 5/157 frames from video (1).avi
# Processed 10/157 frames from video (1).avi
# Processed 15/157 frames from video (1).avi
# Processed 20/157 frames from video (1).avi
# Processed 25/157 frames from video (1).avi
# Processed 30/157 frames from video (1).avi
# Processed 35/157 frames from video (1).avi
# Processed 40/157 frames from video (1).avi
# Processed 45/157 frames from video (1).avi
# Processed 50/157 frames from video (1).avi
# Processed 55/157 frames from video (1).avi
# Processed 60/157 frames from video (1).avi
# Processed 65/157 frames from video (1).avi
# Processed 70/157 frames from video (1).avi
# Processed 75/157 frames from video (1).avi
# Processed 80/157 frames from video (1).avi
# Processed 85/157 frames from video (1).avi
# Processed 90/157 frames from video (1).avi
# Processed 95/157 frames from video (1).avi
# Processed 100/157 frames from video (1).avi
# Processed 105/157 frames from video (1).avi
# Processed 110/157 frames from video (1).avi
# Processed 115/157 frames from video (1).avi
# Processed 120/157 frames from video (1).avi
# Processed 125/157 frames from video (1).avi
# Processed 130/157 frames from video (1).avi
# Processed 135/157 frames from video (1).avi
# Processed 140/157 frames from video (1).avi
# Processed 145/157 frames from video (1).avi
# Processed 150/157 frames from video (1).avi
# Processed 155/157 frames from video (1).avi
# Video prediction: 1 (True label: 1)
# Processed 157 frames with avg processing time: 0.0519 seconds
# Processing fall video: Coffee_room_01/video (10).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (10).avi
# Video properties: 320x240, 25.0 FPS, 362 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0506 seconds
# Processing fall video: Coffee_room_01/video (11).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (11).avi
# Video properties: 320x240, 25.0 FPS, 483 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0536 seconds
# Processing fall video: Coffee_room_01/video (12).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (12).avi
# Video properties: 320x240, 25.0 FPS, 182 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0528 seconds
# Processing fall video: Coffee_room_01/video (13).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (13).avi
# Video properties: 320x240, 25.0 FPS, 244 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0480 seconds
# Processing fall video: Coffee_room_01/video (14).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (14).avi
# Video properties: 320x240, 25.0 FPS, 176 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0493 seconds
# Processing fall video: Coffee_room_01/video (15).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (15).avi
# Video properties: 320x240, 25.0 FPS, 140 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0503 seconds
# Processing fall video: Coffee_room_01/video (16).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (16).avi
# Video properties: 320x240, 25.0 FPS, 177 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0542 seconds
# Processing fall video: Coffee_room_01/video (17).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (17).avi
# Video properties: 320x240, 25.0 FPS, 158 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0523 seconds
# Processing fall video: Coffee_room_01/video (18).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (18).avi
# Video properties: 320x240, 25.0 FPS, 269 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0503 seconds
# Processing fall video: Coffee_room_01/video (19).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (19).avi
# Video properties: 320x240, 25.0 FPS, 213 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0487 seconds
# Processing fall video: Coffee_room_01/video (2).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (2).avi
# Video properties: 320x240, 25.0 FPS, 306 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0541 seconds
# Processing fall video: Coffee_room_01/video (20).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (20).avi
# Video properties: 320x240, 25.0 FPS, 444 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0523 seconds
# Processing fall video: Coffee_room_01/video (21).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (21).avi
# Video properties: 320x240, 25.0 FPS, 182 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0543 seconds
# Processing fall video: Coffee_room_01/video (22).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (22).avi
# Video properties: 320x240, 25.0 FPS, 229 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0506 seconds
# Processing fall video: Coffee_room_01/video (23).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (23).avi
# Video properties: 320x240, 25.0 FPS, 311 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0486 seconds
# Processing fall video: Coffee_room_01/video (24).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (24).avi
# Video properties: 320x240, 25.0 FPS, 267 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0519 seconds
# Processing fall video: Coffee_room_01/video (25).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (25).avi
# Video properties: 320x240, 25.0 FPS, 262 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0522 seconds
# Processing fall video: Coffee_room_01/video (26).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (26).avi
# Video properties: 320x240, 25.0 FPS, 278 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0471 seconds
# Processing fall video: Coffee_room_01/video (27).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (27).avi
# Video properties: 320x240, 25.0 FPS, 253 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0503 seconds
# Processing fall video: Coffee_room_01/video (28).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (28).avi
# Video properties: 320x240, 25.0 FPS, 175 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0548 seconds
# Processing fall video: Coffee_room_01/video (29).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (29).avi
# Video properties: 320x240, 25.0 FPS, 328 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0567 seconds
# Processing fall video: Coffee_room_01/video (3).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (3).avi
# Video properties: 320x240, 25.0 FPS, 304 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0464 seconds
# Processing fall video: Coffee_room_01/video (30).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (30).avi
# Video properties: 320x240, 25.0 FPS, 145 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0450 seconds
# Processing fall video: Coffee_room_01/video (31).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (31).avi
# Video properties: 320x240, 25.0 FPS, 265 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0537 seconds
# Processing fall video: Coffee_room_01/video (32).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (32).avi
# Video properties: 320x240, 25.0 FPS, 305 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0502 seconds
# Processing fall video: Coffee_room_01/video (33).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (33).avi
# Video properties: 320x240, 25.0 FPS, 227 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0511 seconds
# Processing fall video: Coffee_room_01/video (34).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (34).avi
# Video properties: 320x240, 25.0 FPS, 415 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0510 seconds
# Processing fall video: Coffee_room_01/video (35).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (35).avi
# Video properties: 320x240, 25.0 FPS, 231 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0523 seconds
# Processing fall video: Coffee_room_01/video (36).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (36).avi
# Video properties: 320x240, 25.0 FPS, 1203 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0574 seconds
# Processing fall video: Coffee_room_01/video (37).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (37).avi
# Video properties: 320x240, 25.0 FPS, 206 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0562 seconds
# Processing fall video: Coffee_room_01/video (38).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (38).avi
# Video properties: 320x240, 25.0 FPS, 352 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0527 seconds
# Processing fall video: Coffee_room_01/video (39).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (39).avi
# Video properties: 320x240, 25.0 FPS, 157 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0447 seconds
# Processing fall video: Coffee_room_01/video (4).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (4).avi
# Video properties: 320x240, 25.0 FPS, 207 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0474 seconds
# Processing fall video: Coffee_room_01/video (40).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (40).avi
# Video properties: 320x240, 25.0 FPS, 350 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0547 seconds
# Processing fall video: Coffee_room_01/video (41).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (41).avi
# Video properties: 320x240, 25.0 FPS, 382 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0494 seconds
# Processing fall video: Coffee_room_01/video (42).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (42).avi
# Video properties: 320x240, 25.0 FPS, 159 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0473 seconds
# Processing fall video: Coffee_room_01/video (43).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (43).avi
# Video properties: 320x240, 25.0 FPS, 718 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0532 seconds
# Processing fall video: Coffee_room_01/video (44).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (44).avi
# Video properties: 320x240, 25.0 FPS, 133 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0539 seconds
# Processing fall video: Coffee_room_01/video (45).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (45).avi
# Video properties: 320x240, 25.0 FPS, 215 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0508 seconds
# Processing fall video: Coffee_room_01/video (46).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (46).avi
# Video properties: 320x240, 25.0 FPS, 292 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0518 seconds
# Processing fall video: Coffee_room_01/video (47).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (47).avi
# Video properties: 320x240, 25.0 FPS, 729 frames
# No frames were successfully processed.
# Processing fall video: Coffee_room_01/video (48).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (48).avi
# Video properties: 320x240, 25.0 FPS, 779 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0501 seconds
# Processing fall video: Coffee_room_01/video (5).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (5).avi
# Video properties: 320x240, 25.0 FPS, 181 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0494 seconds
# Processing fall video: Coffee_room_01/video (6).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (6).avi
# Video properties: 320x240, 25.0 FPS, 239 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0519 seconds
# Processing fall video: Coffee_room_01/video (7).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (7).avi
# Video properties: 320x240, 25.0 FPS, 174 frames
# No frames were successfully processed.
# Processing fall video: Coffee_room_01/video (8).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (8).avi
# Video properties: 320x240, 25.0 FPS, 258 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0512 seconds
# Processing fall video: Coffee_room_01/video (9).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_01\Videos\video (9).avi
# Video properties: 320x240, 25.0 FPS, 206 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0551 seconds
# Processing videos in Coffee_room_02/Videos
# Found 14 video files in Coffee_room_02/Videos
# Processing fall video: Coffee_room_02/video (49).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_02\Videos\video (49).avi
# Video properties: 320x240, 25.0 FPS, 492 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0524 seconds
# Processing fall video: Coffee_room_02/video (50).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_02\Videos\video (50).avi
# Video properties: 320x240, 25.0 FPS, 1954 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0449 seconds
# Processing fall video: Coffee_room_02/video (51).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_02\Videos\video (51).avi
# Video properties: 320x240, 25.0 FPS, 203 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0490 seconds
# Processing fall video: Coffee_room_02/video (52).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_02\Videos\video (52).avi
# Video properties: 320x240, 25.0 FPS, 215 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0521 seconds
# Processing fall video: Coffee_room_02/video (53).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_02\Videos\video (53).avi
# Video properties: 320x240, 25.0 FPS, 383 frames
# No frames were successfully processed.
# Processing fall video: Coffee_room_02/video (54).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_02\Videos\video (54).avi
# Video properties: 320x240, 25.0 FPS, 251 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0523 seconds
# Processing fall video: Coffee_room_02/video (55).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_02\Videos\video (55).avi
# Video properties: 320x240, 25.0 FPS, 323 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0560 seconds
# Processing fall video: Coffee_room_02/video (56).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_02\Videos\video (56).avi
# Video properties: 320x240, 25.0 FPS, 431 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0485 seconds
# Processing fall video: Coffee_room_02/video (57).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_02\Videos\video (57).avi
# Video properties: 320x240, 25.0 FPS, 563 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0501 seconds
# Processing fall video: Coffee_room_02/video (58).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_02\Videos\video (58).avi
# Video properties: 320x240, 25.0 FPS, 311 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0509 seconds
# Processing fall video: Coffee_room_02/video (59).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_02\Videos\video (59).avi
# Video properties: 320x240, 25.0 FPS, 251 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0565 seconds
# Processing fall video: Coffee_room_02/video (60).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_02\Videos\video (60).avi
# Video properties: 320x240, 25.0 FPS, 275 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0556 seconds
# Processing fall video: Coffee_room_02/video (62).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_02\Videos\video (62).avi
# Video properties: 320x240, 25.0 FPS, 282 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0577 seconds
# Processing fall video: Coffee_room_02/video (64).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Coffee_room_02\Videos\video (64).avi
# Video properties: 320x240, 25.0 FPS, 212 frames
# Video prediction: 0 (True label: 1)
# Processed 1 frames with avg processing time: 0.0475 seconds
# Processing videos in Home_01/Videos
# Found 30 video files in Home_01/Videos
# Processing fall video: Home_01/video (1).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Home_01\Videos\video (1).avi
# Video properties: 320x240, 24.0003840061441 FPS, 264 frames
# Processed 5/264 frames from video (1).avi
# Processed 10/264 frames from video (1).avi
# Processed 15/264 frames from video (1).avi
# Processed 20/264 frames from video (1).avi
# Processed 25/264 frames from video (1).avi
# Processed 30/264 frames from video (1).avi
# Processed 35/264 frames from video (1).avi
# Processed 40/264 frames from video (1).avi
# Processed 45/264 frames from video (1).avi
# Processed 50/264 frames from video (1).avi
# Processed 55/264 frames from video (1).avi
# Processed 60/264 frames from video (1).avi
# Processed 65/264 frames from video (1).avi
# Processed 70/264 frames from video (1).avi
# Processed 75/264 frames from video (1).avi
# Processed 80/264 frames from video (1).avi
# Processed 85/264 frames from video (1).avi
# Processed 90/264 frames from video (1).avi
# Processed 95/264 frames from video (1).avi
# Processed 100/264 frames from video (1).avi
# Processed 105/264 frames from video (1).avi
# Processed 110/264 frames from video (1).avi
# Processed 115/264 frames from video (1).avi
# Processed 120/264 frames from video (1).avi
# Processed 125/264 frames from video (1).avi
# Processed 130/264 frames from video (1).avi
# Processed 135/264 frames from video (1).avi
# Processed 140/264 frames from video (1).avi
# Processed 145/264 frames from video (1).avi
# Processed 150/264 frames from video (1).avi
# Processed 155/264 frames from video (1).avi
# Processed 160/264 frames from video (1).avi
# Processed 165/264 frames from video (1).avi
# Processed 170/264 frames from video (1).avi
# Processed 175/264 frames from video (1).avi
# Processed 180/264 frames from video (1).avi
# Processed 185/264 frames from video (1).avi
# Processed 190/264 frames from video (1).avi
# Processed 195/264 frames from video (1).avi
# Processed 200/264 frames from video (1).avi
# Processed 205/264 frames from video (1).avi
# Processed 210/264 frames from video (1).avi
# Processed 215/264 frames from video (1).avi
# Processed 220/264 frames from video (1).avi
# Processed 225/264 frames from video (1).avi
# Processed 230/264 frames from video (1).avi
# Processed 235/264 frames from video (1).avi
# Processed 240/264 frames from video (1).avi
# Processed 245/264 frames from video (1).avi
# Processed 250/264 frames from video (1).avi
# Processed 255/264 frames from video (1).avi
# Processed 260/264 frames from video (1).avi
# Video prediction: 1 (True label: 1)
# Processed 264 frames with avg processing time: 0.0503 seconds
# Processing fall video: Home_01/video (10).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Home_01\Videos\video (10).avi
# Video properties: 320x240, 24.0003840061441 FPS, 312 frames
# Processed 5/312 frames from video (10).avi
# Processed 10/312 frames from video (10).avi
# Processed 15/312 frames from video (10).avi
# Processed 20/312 frames from video (10).avi
# Processed 25/312 frames from video (10).avi
# Processed 30/312 frames from video (10).avi
# Processed 35/312 frames from video (10).avi
# Processed 40/312 frames from video (10).avi
# Processed 45/312 frames from video (10).avi
# Processed 50/312 frames from video (10).avi
# Processed 55/312 frames from video (10).avi
# Processed 60/312 frames from video (10).avi
# Processed 65/312 frames from video (10).avi
# Processed 70/312 frames from video (10).avi
# Processed 75/312 frames from video (10).avi
# Processed 80/312 frames from video (10).avi
# Processed 85/312 frames from video (10).avi
# Processed 90/312 frames from video (10).avi
# Processed 95/312 frames from video (10).avi
# Processed 100/312 frames from video (10).avi
# Processed 105/312 frames from video (10).avi
# Processed 110/312 frames from video (10).avi
# Processed 115/312 frames from video (10).avi
# Processed 120/312 frames from video (10).avi
# Processed 125/312 frames from video (10).avi
# Processed 130/312 frames from video (10).avi
# Processed 135/312 frames from video (10).avi
# Processed 140/312 frames from video (10).avi
# Processed 145/312 frames from video (10).avi
# Processed 150/312 frames from video (10).avi
# Processed 155/312 frames from video (10).avi
# Processed 160/312 frames from video (10).avi
# Processed 165/312 frames from video (10).avi
# Processed 170/312 frames from video (10).avi
# Processed 175/312 frames from video (10).avi
# Processed 180/312 frames from video (10).avi
# Processed 185/312 frames from video (10).avi
# Processed 190/312 frames from video (10).avi
# Processed 195/312 frames from video (10).avi
# Processed 200/312 frames from video (10).avi
# Processed 205/312 frames from video (10).avi
# Processed 210/312 frames from video (10).avi
# Processed 215/312 frames from video (10).avi
# Processed 220/312 frames from video (10).avi
# Processed 225/312 frames from video (10).avi
# Processed 230/312 frames from video (10).avi
# Processed 235/312 frames from video (10).avi
# Processed 240/312 frames from video (10).avi
# Processed 245/312 frames from video (10).avi
# Processed 250/312 frames from video (10).avi
# Processed 255/312 frames from video (10).avi
# Processed 260/312 frames from video (10).avi
# Processed 265/312 frames from video (10).avi
# Processed 270/312 frames from video (10).avi
# Processed 275/312 frames from video (10).avi
# Processed 280/312 frames from video (10).avi
# Processed 285/312 frames from video (10).avi
# Processed 290/312 frames from video (10).avi
# Processed 295/312 frames from video (10).avi
# Processed 300/312 frames from video (10).avi
# Processed 305/312 frames from video (10).avi
# Processed 310/312 frames from video (10).avi
# Video prediction: 1 (True label: 1)
# Processed 312 frames with avg processing time: 0.0480 seconds
# Processing fall video: Home_01/video (11).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Home_01\Videos\video (11).avi
# Video properties: 320x240, 24.0003840061441 FPS, 312 frames
# Processed 5/312 frames from video (11).avi
# Processed 10/312 frames from video (11).avi
# Processed 15/312 frames from video (11).avi
# Processed 20/312 frames from video (11).avi
# Processed 25/312 frames from video (11).avi
# Processed 30/312 frames from video (11).avi
# Processed 35/312 frames from video (11).avi
# Processed 40/312 frames from video (11).avi
# Processed 45/312 frames from video (11).avi
# Processed 50/312 frames from video (11).avi
# Processed 55/312 frames from video (11).avi
# Processed 60/312 frames from video (11).avi
# Processed 65/312 frames from video (11).avi
# Processed 70/312 frames from video (11).avi
# Processed 75/312 frames from video (11).avi
# Processed 80/312 frames from video (11).avi
# Processed 85/312 frames from video (11).avi
# Processed 90/312 frames from video (11).avi
# Processed 95/312 frames from video (11).avi
# Processed 100/312 frames from video (11).avi
# Processed 105/312 frames from video (11).avi
# Processed 110/312 frames from video (11).avi
# Processed 115/312 frames from video (11).avi
# Processed 120/312 frames from video (11).avi
# Processed 125/312 frames from video (11).avi
# Processed 130/312 frames from video (11).avi
# Processed 135/312 frames from video (11).avi
# Processed 140/312 frames from video (11).avi
# Processed 145/312 frames from video (11).avi
# Processed 150/312 frames from video (11).avi
# Processed 155/312 frames from video (11).avi
# Processed 160/312 frames from video (11).avi
# Processed 165/312 frames from video (11).avi
# Processed 170/312 frames from video (11).avi
# Processed 175/312 frames from video (11).avi
# Processed 180/312 frames from video (11).avi
# Processed 185/312 frames from video (11).avi
# Processed 190/312 frames from video (11).avi
# Processed 195/312 frames from video (11).avi
# Processed 200/312 frames from video (11).avi
# Processed 205/312 frames from video (11).avi
# Processed 210/312 frames from video (11).avi
# Processed 215/312 frames from video (11).avi
# Processed 220/312 frames from video (11).avi
# Processed 225/312 frames from video (11).avi
# Processed 230/312 frames from video (11).avi
# Processed 235/312 frames from video (11).avi
# Processed 240/312 frames from video (11).avi
# Processed 245/312 frames from video (11).avi
# Processed 250/312 frames from video (11).avi
# Processed 255/312 frames from video (11).avi
# Processed 260/312 frames from video (11).avi
# Processed 265/312 frames from video (11).avi
# Processed 270/312 frames from video (11).avi
# Processed 275/312 frames from video (11).avi
# Processed 280/312 frames from video (11).avi
# Processed 285/312 frames from video (11).avi
# Processed 290/312 frames from video (11).avi
# Processed 295/312 frames from video (11).avi
# Processed 300/312 frames from video (11).avi
# Processed 305/312 frames from video (11).avi
# Processed 310/312 frames from video (11).avi
# Video prediction: 0 (True label: 1)
# Processed 312 frames with avg processing time: 0.0472 seconds
# Processing fall video: Home_01/video (12).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Home_01\Videos\video (12).avi
# Video properties: 320x180, 24.0003840061441 FPS, 216 frames
# Processed 5/216 frames from video (12).avi
# Processed 10/216 frames from video (12).avi
# Processed 15/216 frames from video (12).avi
# Processed 20/216 frames from video (12).avi
# Processed 25/216 frames from video (12).avi
# Processed 30/216 frames from video (12).avi
# Processed 35/216 frames from video (12).avi
# Processed 40/216 frames from video (12).avi
# Processed 45/216 frames from video (12).avi
# Processed 50/216 frames from video (12).avi
# Processed 55/216 frames from video (12).avi
# Processed 60/216 frames from video (12).avi
# Processed 65/216 frames from video (12).avi
# Processed 70/216 frames from video (12).avi
# Processed 75/216 frames from video (12).avi
# Processed 80/216 frames from video (12).avi
# Processed 85/216 frames from video (12).avi
# Processed 90/216 frames from video (12).avi
# Processed 95/216 frames from video (12).avi
# Processed 100/216 frames from video (12).avi
# Processed 105/216 frames from video (12).avi
# Processed 110/216 frames from video (12).avi
# Processed 115/216 frames from video (12).avi
# Processed 120/216 frames from video (12).avi
# Processed 125/216 frames from video (12).avi
# Processed 130/216 frames from video (12).avi
# Processed 135/216 frames from video (12).avi
# Processed 140/216 frames from video (12).avi
# Processed 145/216 frames from video (12).avi
# Processed 150/216 frames from video (12).avi
# Processed 155/216 frames from video (12).avi
# Processed 160/216 frames from video (12).avi
# Processed 165/216 frames from video (12).avi
# Processed 170/216 frames from video (12).avi
# Processed 175/216 frames from video (12).avi
# Processed 180/216 frames from video (12).avi
# Processed 185/216 frames from video (12).avi
# Processed 190/216 frames from video (12).avi
# Processed 195/216 frames from video (12).avi
# Processed 200/216 frames from video (12).avi
# Processed 205/216 frames from video (12).avi
# Processed 210/216 frames from video (12).avi
# Processed 215/216 frames from video (12).avi
# Video prediction: 1 (True label: 1)
# Processed 216 frames with avg processing time: 0.0486 seconds
# Processing fall video: Home_01/video (13).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Home_01\Videos\video (13).avi
# Video properties: 320x180, 24.0003840061441 FPS, 240 frames
# Processed 5/240 frames from video (13).avi
# Processed 10/240 frames from video (13).avi
# Processed 15/240 frames from video (13).avi
# Processed 20/240 frames from video (13).avi
# Processed 25/240 frames from video (13).avi
# Processed 30/240 frames from video (13).avi
# Processed 35/240 frames from video (13).avi
# Processed 40/240 frames from video (13).avi
# Processed 45/240 frames from video (13).avi
# Processed 50/240 frames from video (13).avi
# Processed 55/240 frames from video (13).avi
# Processed 60/240 frames from video (13).avi
# Processed 65/240 frames from video (13).avi
# Processed 70/240 frames from video (13).avi
# Processed 75/240 frames from video (13).avi
# Processed 80/240 frames from video (13).avi
# Processed 85/240 frames from video (13).avi
# Processed 90/240 frames from video (13).avi
# Processed 95/240 frames from video (13).avi
# Processed 100/240 frames from video (13).avi
# Processed 105/240 frames from video (13).avi
# Processed 110/240 frames from video (13).avi
# Processed 115/240 frames from video (13).avi
# Processed 120/240 frames from video (13).avi
# Processed 125/240 frames from video (13).avi
# Processed 130/240 frames from video (13).avi
# Processed 135/240 frames from video (13).avi
# Processed 140/240 frames from video (13).avi
# Processed 145/240 frames from video (13).avi
# Processed 150/240 frames from video (13).avi
# Processed 155/240 frames from video (13).avi
# Processed 160/240 frames from video (13).avi
# Processed 165/240 frames from video (13).avi
# Processed 170/240 frames from video (13).avi
# Processed 175/240 frames from video (13).avi
# Processed 180/240 frames from video (13).avi
# Processed 185/240 frames from video (13).avi
# Processed 190/240 frames from video (13).avi
# Processed 195/240 frames from video (13).avi
# Processed 200/240 frames from video (13).avi
# Processed 205/240 frames from video (13).avi
# Processed 210/240 frames from video (13).avi
# Processed 215/240 frames from video (13).avi
# Processed 220/240 frames from video (13).avi
# Processed 225/240 frames from video (13).avi
# Processed 230/240 frames from video (13).avi
# Processed 235/240 frames from video (13).avi
# Processed 240/240 frames from video (13).avi
# Video prediction: 1 (True label: 1)
# Processed 240 frames with avg processing time: 0.0470 seconds
# Processing fall video: Home_01/video (14).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Home_01\Videos\video (14).avi
# Video properties: 320x180, 24.0003840061441 FPS, 288 frames
# Processed 5/288 frames from video (14).avi
# Processed 10/288 frames from video (14).avi
# Processed 15/288 frames from video (14).avi
# Processed 20/288 frames from video (14).avi
# Processed 25/288 frames from video (14).avi
# Processed 30/288 frames from video (14).avi
# Processed 35/288 frames from video (14).avi
# Processed 40/288 frames from video (14).avi
# Processed 45/288 frames from video (14).avi
# Processed 50/288 frames from video (14).avi
# Processed 55/288 frames from video (14).avi
# Processed 60/288 frames from video (14).avi
# Processed 65/288 frames from video (14).avi
# Processed 70/288 frames from video (14).avi
# Processed 75/288 frames from video (14).avi
# Processed 80/288 frames from video (14).avi
# Processed 85/288 frames from video (14).avi
# Processed 90/288 frames from video (14).avi
# Processed 95/288 frames from video (14).avi
# Processed 100/288 frames from video (14).avi
# Processed 105/288 frames from video (14).avi
# Processed 110/288 frames from video (14).avi
# Processed 115/288 frames from video (14).avi
# Processed 120/288 frames from video (14).avi
# Processed 125/288 frames from video (14).avi
# Processed 130/288 frames from video (14).avi
# Processed 135/288 frames from video (14).avi
# Processed 140/288 frames from video (14).avi
# Processed 145/288 frames from video (14).avi
# Processed 150/288 frames from video (14).avi
# Processed 155/288 frames from video (14).avi
# Processed 160/288 frames from video (14).avi
# Processed 165/288 frames from video (14).avi
# Processed 170/288 frames from video (14).avi
# Processed 175/288 frames from video (14).avi
# Processed 180/288 frames from video (14).avi
# Processed 185/288 frames from video (14).avi
# Processed 190/288 frames from video (14).avi
# Processed 195/288 frames from video (14).avi
# Processed 200/288 frames from video (14).avi
# Processed 205/288 frames from video (14).avi
# Processed 210/288 frames from video (14).avi
# Processed 215/288 frames from video (14).avi
# Processed 220/288 frames from video (14).avi
# Processed 225/288 frames from video (14).avi
# Processed 230/288 frames from video (14).avi
# Processed 235/288 frames from video (14).avi
# Processed 240/288 frames from video (14).avi
# Processed 245/288 frames from video (14).avi
# Processed 250/288 frames from video (14).avi
# Processed 255/288 frames from video (14).avi
# Processed 260/288 frames from video (14).avi
# Processed 265/288 frames from video (14).avi
# Processed 270/288 frames from video (14).avi
# Processed 275/288 frames from video (14).avi
# Processed 280/288 frames from video (14).avi
# Processed 285/288 frames from video (14).avi
# Video prediction: 0 (True label: 1)
# Processed 288 frames with avg processing time: 0.0479 seconds
# Processing fall video: Home_01/video (15).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Home_01\Videos\video (15).avi
# Video properties: 320x180, 24.0003840061441 FPS, 238 frames
# Processed 5/238 frames from video (15).avi
# Processed 10/238 frames from video (15).avi
# Processed 15/238 frames from video (15).avi
# Processed 20/238 frames from video (15).avi
# Processed 25/238 frames from video (15).avi
# Processed 30/238 frames from video (15).avi
# Processed 35/238 frames from video (15).avi
# Processed 40/238 frames from video (15).avi
# Processed 45/238 frames from video (15).avi
# Processed 50/238 frames from video (15).avi
# Processed 55/238 frames from video (15).avi
# Processed 60/238 frames from video (15).avi
# Processed 65/238 frames from video (15).avi
# Processed 70/238 frames from video (15).avi
# Processed 75/238 frames from video (15).avi
# Processed 80/238 frames from video (15).avi
# Processed 85/238 frames from video (15).avi
# Processed 90/238 frames from video (15).avi
# Processed 95/238 frames from video (15).avi
# Processed 100/238 frames from video (15).avi
# Processed 105/238 frames from video (15).avi
# Processed 110/238 frames from video (15).avi
# Processed 115/238 frames from video (15).avi
# Processed 120/238 frames from video (15).avi
# Processed 125/238 frames from video (15).avi
# Processed 130/238 frames from video (15).avi
# Processed 135/238 frames from video (15).avi
# Processed 140/238 frames from video (15).avi
# Processed 145/238 frames from video (15).avi
# Processed 150/238 frames from video (15).avi
# Processed 155/238 frames from video (15).avi
# Processed 160/238 frames from video (15).avi
# Processed 165/238 frames from video (15).avi
# Processed 170/238 frames from video (15).avi
# Processed 175/238 frames from video (15).avi
# Processed 180/238 frames from video (15).avi
# Processed 185/238 frames from video (15).avi
# Processed 190/238 frames from video (15).avi
# Processed 195/238 frames from video (15).avi
# Processed 200/238 frames from video (15).avi
# Processed 205/238 frames from video (15).avi
# Processed 210/238 frames from video (15).avi
# Processed 215/238 frames from video (15).avi
# Processed 220/238 frames from video (15).avi
# Processed 225/238 frames from video (15).avi
# Processed 230/238 frames from video (15).avi
# Processed 235/238 frames from video (15).avi
# Video prediction: 1 (True label: 1)
# Processed 238 frames with avg processing time: 0.0494 seconds
# Processing fall video: Home_01/video (16).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Home_01\Videos\video (16).avi
# Video properties: 320x180, 24.0003840061441 FPS, 264 frames
# Processed 5/264 frames from video (16).avi
# Processed 10/264 frames from video (16).avi
# Processed 15/264 frames from video (16).avi
# Processed 20/264 frames from video (16).avi
# Processed 25/264 frames from video (16).avi
# Processed 30/264 frames from video (16).avi
# Processed 35/264 frames from video (16).avi
# Processed 40/264 frames from video (16).avi
# Processed 45/264 frames from video (16).avi
# Processed 50/264 frames from video (16).avi
# Processed 55/264 frames from video (16).avi
# Processed 60/264 frames from video (16).avi
# Processed 65/264 frames from video (16).avi
# Processed 70/264 frames from video (16).avi
# Processed 75/264 frames from video (16).avi
# Processed 80/264 frames from video (16).avi
# Processed 85/264 frames from video (16).avi
# Processed 90/264 frames from video (16).avi
# Processed 95/264 frames from video (16).avi
# Processed 100/264 frames from video (16).avi
# Processed 105/264 frames from video (16).avi
# Processed 110/264 frames from video (16).avi
# Processed 115/264 frames from video (16).avi
# Processed 120/264 frames from video (16).avi
# Processed 125/264 frames from video (16).avi
# Processed 130/264 frames from video (16).avi
# Processed 135/264 frames from video (16).avi
# Processed 140/264 frames from video (16).avi
# Processed 145/264 frames from video (16).avi
# Processed 150/264 frames from video (16).avi
# Processed 155/264 frames from video (16).avi
# Processed 160/264 frames from video (16).avi
# Processed 165/264 frames from video (16).avi
# Processed 170/264 frames from video (16).avi
# Processed 175/264 frames from video (16).avi
# Processed 180/264 frames from video (16).avi
# Processed 185/264 frames from video (16).avi
# Processed 190/264 frames from video (16).avi
# Processed 195/264 frames from video (16).avi
# Processed 200/264 frames from video (16).avi
# Processed 205/264 frames from video (16).avi
# Processed 210/264 frames from video (16).avi
# Processed 215/264 frames from video (16).avi
# Processed 220/264 frames from video (16).avi
# Processed 225/264 frames from video (16).avi
# Processed 230/264 frames from video (16).avi
# Processed 235/264 frames from video (16).avi
# Processed 240/264 frames from video (16).avi
# Processed 245/264 frames from video (16).avi
# Processed 250/264 frames from video (16).avi
# Processed 255/264 frames from video (16).avi
# Processed 260/264 frames from video (16).avi
# Video prediction: 1 (True label: 1)
# Processed 264 frames with avg processing time: 0.0525 seconds
# Processing fall video: Home_01/video (17).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Home_01\Videos\video (17).avi
# Video properties: 320x180, 24.0003840061441 FPS, 240 frames
# Processed 5/240 frames from video (17).avi
# Processed 10/240 frames from video (17).avi
# Processed 15/240 frames from video (17).avi
# Processed 20/240 frames from video (17).avi
# Processed 25/240 frames from video (17).avi
# Processed 30/240 frames from video (17).avi
# Processed 35/240 frames from video (17).avi
# Processed 40/240 frames from video (17).avi
# Processed 45/240 frames from video (17).avi
# Processed 50/240 frames from video (17).avi
# Processed 55/240 frames from video (17).avi
# Processed 60/240 frames from video (17).avi
# Processed 65/240 frames from video (17).avi
# Processed 70/240 frames from video (17).avi
# Processed 75/240 frames from video (17).avi
# Processed 80/240 frames from video (17).avi
# Processed 85/240 frames from video (17).avi
# Processed 90/240 frames from video (17).avi
# Processed 95/240 frames from video (17).avi
# Processed 100/240 frames from video (17).avi
# Processed 105/240 frames from video (17).avi
# Processed 110/240 frames from video (17).avi
# Processed 115/240 frames from video (17).avi
# Processed 120/240 frames from video (17).avi
# Processed 125/240 frames from video (17).avi
# Processed 130/240 frames from video (17).avi
# Processed 135/240 frames from video (17).avi
# Processed 140/240 frames from video (17).avi
# Processed 145/240 frames from video (17).avi
# Processed 150/240 frames from video (17).avi
# Processed 155/240 frames from video (17).avi
# Processed 160/240 frames from video (17).avi
# Processed 165/240 frames from video (17).avi
# Processed 170/240 frames from video (17).avi
# Processed 175/240 frames from video (17).avi
# Processed 180/240 frames from video (17).avi
# Processed 185/240 frames from video (17).avi
# Processed 190/240 frames from video (17).avi
# Processed 195/240 frames from video (17).avi
# Processed 200/240 frames from video (17).avi
# Processed 205/240 frames from video (17).avi
# Processed 210/240 frames from video (17).avi
# Processed 215/240 frames from video (17).avi
# Processed 220/240 frames from video (17).avi
# Processed 225/240 frames from video (17).avi
# Processed 230/240 frames from video (17).avi
# Processed 235/240 frames from video (17).avi
# Processed 240/240 frames from video (17).avi
# Video prediction: 1 (True label: 1)
# Processed 240 frames with avg processing time: 0.0530 seconds
# Processing fall video: Home_01/video (18).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Home_01\Videos\video (18).avi
# Video properties: 320x180, 24.0003840061441 FPS, 216 frames
# Processed 5/216 frames from video (18).avi
# Processed 10/216 frames from video (18).avi
# Processed 15/216 frames from video (18).avi
# Processed 20/216 frames from video (18).avi
# Processed 25/216 frames from video (18).avi
# Processed 30/216 frames from video (18).avi
# Processed 35/216 frames from video (18).avi
# Processed 40/216 frames from video (18).avi
# Processed 45/216 frames from video (18).avi
# Processed 50/216 frames from video (18).avi
# Processed 55/216 frames from video (18).avi
# Processed 60/216 frames from video (18).avi
# Processed 65/216 frames from video (18).avi
# Processed 70/216 frames from video (18).avi
# Processed 75/216 frames from video (18).avi
# Processed 80/216 frames from video (18).avi
# Processed 85/216 frames from video (18).avi
# Processed 90/216 frames from video (18).avi
# Processed 95/216 frames from video (18).avi
# Processed 100/216 frames from video (18).avi
# Processed 105/216 frames from video (18).avi
# Processed 110/216 frames from video (18).avi
# Processed 115/216 frames from video (18).avi
# Processed 120/216 frames from video (18).avi
# Processed 125/216 frames from video (18).avi
# Processed 130/216 frames from video (18).avi
# Processed 135/216 frames from video (18).avi
# Processed 140/216 frames from video (18).avi
# Processed 145/216 frames from video (18).avi
# Processed 150/216 frames from video (18).avi
# Processed 155/216 frames from video (18).avi
# Processed 160/216 frames from video (18).avi
# Processed 165/216 frames from video (18).avi
# Processed 170/216 frames from video (18).avi
# Processed 175/216 frames from video (18).avi
# Processed 180/216 frames from video (18).avi
# Processed 185/216 frames from video (18).avi
# Processed 190/216 frames from video (18).avi
# Processed 195/216 frames from video (18).avi
# Processed 200/216 frames from video (18).avi
# Processed 205/216 frames from video (18).avi
# Processed 210/216 frames from video (18).avi
# Processed 215/216 frames from video (18).avi
# Video prediction: 1 (True label: 1)
# Processed 216 frames with avg processing time: 0.0508 seconds
# Processing fall video: Home_01/video (19).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Fall\Home_01\Videos\video (19).avi
# Video properties: 320x180, 24.0003840061441 FPS, 192 frames
# Processed 5/192 frames from video (19).avi
# Processed 10/192 frames from video (19).avi
# Processed 15/192 frames from video (19).avi
# Processed 20/192 frames from video (19).avi
# Processed 25/192 frames from video (19).avi
# Processed 30/192 frames from video (19).avi
# Processed 35/192 frames from video (19).avi
# Processed 40/192 frames from video (19).avi
# Processed 45/192 frames from video (19).avi
# Processed 50/192 frames from video (19).avi
# Processed 55/192 frames from video (19).avi
# Processed 60/192 frames from video (19).avi
# Processed 65/192 frames from video (19).avi
# Processed 70/192 frames from video (19).avi
# Processed 75/192 frames from video (19).avi
# Processed 80/192 frames from video (19).avi
# Processed 85/192 frames from video (19).avi
# ...
# Processed 1035/1247 frames from video (30).avi
# Processed 1040/1247 frames from video (30).avi
# Processed 1045/1247 frames from video (30).avi
# Processed 1050/1247 frames from video (30).avi
# Processed 1055/1247 frames from video (30).avi
# Processed 1060/1247 frames from video (30).avi
# Processed 1065/1247 frames from video (30).avi
# Processed 1070/1247 frames from video (30).avi
# Processed 1075/1247 frames from video (30).avi
# Processed 1080/1247 frames from video (30).avi
# Processed 1085/1247 frames from video (30).avi
# Processed 1090/1247 frames from video (30).avi
# Processed 1095/1247 frames from video (30).avi
# Processed 1100/1247 frames from video (30).avi
# Processed 1105/1247 frames from video (30).avi
# Processed 1110/1247 frames from video (30).avi
# Processed 1115/1247 frames from video (30).avi
# Processed 1120/1247 frames from video (30).avi
# Processed 1125/1247 frames from video (30).avi
# Processed 1130/1247 frames from video (30).avi
# Processed 1135/1247 frames from video (30).avi
# Processed 1140/1247 frames from video (30).avi
# Processed 1145/1247 frames from video (30).avi
# Processed 1150/1247 frames from video (30).avi
# Processed 1155/1247 frames from video (30).avi
# Processed 1160/1247 frames from video (30).avi
# Processed 1165/1247 frames from video (30).avi
# Processed 1170/1247 frames from video (30).avi
# Processed 1175/1247 frames from video (30).avi
# Processed 1180/1247 frames from video (30).avi
# Processed 1185/1247 frames from video (30).avi
# Processed 1190/1247 frames from video (30).avi
# Processed 1195/1247 frames from video (30).avi
# Processed 1200/1247 frames from video (30).avi
# Processed 1205/1247 frames from video (30).avi
# Processed 1210/1247 frames from video (30).avi
# Processed 1215/1247 frames from video (30).avi
# Processed 1220/1247 frames from video (30).avi
# Processed 1225/1247 frames from video (30).avi
# Processed 1230/1247 frames from video (30).avi
# Processed 1235/1247 frames from video (30).avi
# Processed 1240/1247 frames from video (30).avi
# Processed 1245/1247 frames from video (30).avi
# Video prediction: 1 (True label: 0)
# Processed 1247 frames with avg processing time: 0.3285 seconds
# Processing non-fall video: Office/video (31).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Non Fall\Office\Videos\video (31).avi
# Video properties: 320x240, 25.0 FPS, 203 frames
# Processed 5/203 frames from video (31).avi
# Processed 10/203 frames from video (31).avi
# Processed 15/203 frames from video (31).avi
# Processed 20/203 frames from video (31).avi
# Processed 25/203 frames from video (31).avi
# Processed 30/203 frames from video (31).avi
# Processed 35/203 frames from video (31).avi
# Processed 40/203 frames from video (31).avi
# Processed 45/203 frames from video (31).avi
# Processed 50/203 frames from video (31).avi
# Processed 55/203 frames from video (31).avi
# Processed 60/203 frames from video (31).avi
# Processed 65/203 frames from video (31).avi
# Processed 70/203 frames from video (31).avi
# Processed 75/203 frames from video (31).avi
# Processed 80/203 frames from video (31).avi
# Processed 85/203 frames from video (31).avi
# Processed 90/203 frames from video (31).avi
# Processed 95/203 frames from video (31).avi
# Processed 100/203 frames from video (31).avi
# Processed 105/203 frames from video (31).avi
# Processed 110/203 frames from video (31).avi
# Processed 115/203 frames from video (31).avi
# Processed 120/203 frames from video (31).avi
# Processed 125/203 frames from video (31).avi
# Processed 130/203 frames from video (31).avi
# Processed 135/203 frames from video (31).avi
# Processed 140/203 frames from video (31).avi
# Processed 145/203 frames from video (31).avi
# Processed 150/203 frames from video (31).avi
# Processed 155/203 frames from video (31).avi
# Processed 160/203 frames from video (31).avi
# Processed 165/203 frames from video (31).avi
# Processed 170/203 frames from video (31).avi
# Processed 175/203 frames from video (31).avi
# Processed 180/203 frames from video (31).avi
# Processed 185/203 frames from video (31).avi
# Processed 190/203 frames from video (31).avi
# Processed 195/203 frames from video (31).avi
# Processed 200/203 frames from video (31).avi
# Video prediction: 0 (True label: 0)
# Processed 203 frames with avg processing time: 0.0335 seconds
# Processing non-fall video: Office/video (32).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Non Fall\Office\Videos\video (32).avi
# Video properties: 320x240, 25.0 FPS, 544 frames
# Processed 5/544 frames from video (32).avi
# Processed 10/544 frames from video (32).avi
# Processed 15/544 frames from video (32).avi
# Processed 20/544 frames from video (32).avi
# Processed 25/544 frames from video (32).avi
# Processed 30/544 frames from video (32).avi
# Processed 35/544 frames from video (32).avi
# Processed 40/544 frames from video (32).avi
# Processed 45/544 frames from video (32).avi
# Processed 50/544 frames from video (32).avi
# Processed 55/544 frames from video (32).avi
# Processed 60/544 frames from video (32).avi
# Processed 65/544 frames from video (32).avi
# Processed 70/544 frames from video (32).avi
# Processed 75/544 frames from video (32).avi
# Processed 80/544 frames from video (32).avi
# Processed 85/544 frames from video (32).avi
# Processed 90/544 frames from video (32).avi
# Processed 95/544 frames from video (32).avi
# Processed 100/544 frames from video (32).avi
# Processed 105/544 frames from video (32).avi
# Processed 110/544 frames from video (32).avi
# Processed 115/544 frames from video (32).avi
# Processed 120/544 frames from video (32).avi
# Processed 125/544 frames from video (32).avi
# Processed 130/544 frames from video (32).avi
# Processed 135/544 frames from video (32).avi
# Processed 140/544 frames from video (32).avi
# Processed 145/544 frames from video (32).avi
# Processed 150/544 frames from video (32).avi
# Processed 155/544 frames from video (32).avi
# Processed 160/544 frames from video (32).avi
# Processed 165/544 frames from video (32).avi
# Processed 170/544 frames from video (32).avi
# Processed 175/544 frames from video (32).avi
# Processed 180/544 frames from video (32).avi
# Processed 185/544 frames from video (32).avi
# Processed 190/544 frames from video (32).avi
# Processed 195/544 frames from video (32).avi
# Processed 200/544 frames from video (32).avi
# Processed 205/544 frames from video (32).avi
# Processed 210/544 frames from video (32).avi
# Processed 215/544 frames from video (32).avi
# Processed 220/544 frames from video (32).avi
# Processed 225/544 frames from video (32).avi
# Processed 230/544 frames from video (32).avi
# Processed 235/544 frames from video (32).avi
# Processed 240/544 frames from video (32).avi
# Processed 245/544 frames from video (32).avi
# Processed 250/544 frames from video (32).avi
# Processed 255/544 frames from video (32).avi
# Processed 260/544 frames from video (32).avi
# Processed 265/544 frames from video (32).avi
# Processed 270/544 frames from video (32).avi
# Processed 275/544 frames from video (32).avi
# Processed 280/544 frames from video (32).avi
# Processed 285/544 frames from video (32).avi
# Processed 290/544 frames from video (32).avi
# Processed 295/544 frames from video (32).avi
# Processed 300/544 frames from video (32).avi
# Processed 305/544 frames from video (32).avi
# Processed 310/544 frames from video (32).avi
# Processed 315/544 frames from video (32).avi
# Processed 320/544 frames from video (32).avi
# Processed 325/544 frames from video (32).avi
# Processed 330/544 frames from video (32).avi
# Processed 335/544 frames from video (32).avi
# Processed 340/544 frames from video (32).avi
# Processed 345/544 frames from video (32).avi
# Processed 350/544 frames from video (32).avi
# Processed 355/544 frames from video (32).avi
# Processed 360/544 frames from video (32).avi
# Processed 365/544 frames from video (32).avi
# Processed 370/544 frames from video (32).avi
# Processed 375/544 frames from video (32).avi
# Processed 380/544 frames from video (32).avi
# Processed 385/544 frames from video (32).avi
# Processed 390/544 frames from video (32).avi
# Processed 395/544 frames from video (32).avi
# Processed 400/544 frames from video (32).avi
# Processed 405/544 frames from video (32).avi
# Processed 410/544 frames from video (32).avi
# Processed 415/544 frames from video (32).avi
# Processed 420/544 frames from video (32).avi
# Processed 425/544 frames from video (32).avi
# Processed 430/544 frames from video (32).avi
# Processed 435/544 frames from video (32).avi
# Processed 440/544 frames from video (32).avi
# Processed 445/544 frames from video (32).avi
# Processed 450/544 frames from video (32).avi
# Processed 455/544 frames from video (32).avi
# Processed 460/544 frames from video (32).avi
# Processed 465/544 frames from video (32).avi
# Processed 470/544 frames from video (32).avi
# Processed 475/544 frames from video (32).avi
# Processed 480/544 frames from video (32).avi
# Processed 485/544 frames from video (32).avi
# Processed 490/544 frames from video (32).avi
# Processed 495/544 frames from video (32).avi
# Processed 500/544 frames from video (32).avi
# Processed 505/544 frames from video (32).avi
# Processed 510/544 frames from video (32).avi
# Processed 515/544 frames from video (32).avi
# Processed 520/544 frames from video (32).avi
# Processed 525/544 frames from video (32).avi
# Processed 530/544 frames from video (32).avi
# Processed 535/544 frames from video (32).avi
# Processed 540/544 frames from video (32).avi
# Video prediction: 1 (True label: 0)
# Processed 544 frames with avg processing time: 0.0339 seconds
# Processing non-fall video: Office/video (33).avi
# Opening video file: datasets\le2i\Le2i_Sorted\Non Fall\Office\Videos\video (33).avi
# Video properties: 320x240, 25.0 FPS, 639 frames
# Processed 5/639 frames from video (33).avi
# Processed 10/639 frames from video (33).avi
# Processed 15/639 frames from video (33).avi
# Processed 20/639 frames from video (33).avi
# Processed 25/639 frames from video (33).avi
# Processed 30/639 frames from video (33).avi
# Processed 35/639 frames from video (33).avi
# Processed 40/639 frames from video (33).avi
# Processed 45/639 frames from video (33).avi
# Processed 50/639 frames from video (33).avi
# Processed 55/639 frames from video (33).avi
# Processed 60/639 frames from video (33).avi
# Processed 65/639 frames from video (33).avi
# Processed 70/639 frames from video (33).avi
# Processed 75/639 frames from video (33).avi
# Processed 80/639 frames from video (33).avi
# Processed 85/639 frames from video (33).avi
# Processed 90/639 frames from video (33).avi
# Processed 95/639 frames from video (33).avi
# Processed 100/639 frames from video (33).avi
# Processed 105/639 frames from video (33).avi
# Processed 110/639 frames from video (33).avi
# Processed 115/639 frames from video (33).avi
# Processed 120/639 frames from video (33).avi
# Processed 125/639 frames from video (33).avi
# Processed 130/639 frames from video (33).avi
# Processed 135/639 frames from video (33).avi
# Processed 140/639 frames from video (33).avi
# Processed 145/639 frames from video (33).avi
# Processed 150/639 frames from video (33).avi
# Processed 155/639 frames from video (33).avi
# Processed 160/639 frames from video (33).avi
# Processed 165/639 frames from video (33).avi
# Processed 170/639 frames from video (33).avi
# Processed 175/639 frames from video (33).avi
# Processed 180/639 frames from video (33).avi
# Processed 185/639 frames from video (33).avi
# Processed 190/639 frames from video (33).avi
# Processed 195/639 frames from video (33).avi
# Processed 200/639 frames from video (33).avi
# Processed 205/639 frames from video (33).avi
# Processed 210/639 frames from video (33).avi
# Processed 215/639 frames from video (33).avi
# Processed 220/639 frames from video (33).avi
# Processed 225/639 frames from video (33).avi
# Processed 230/639 frames from video (33).avi
# Processed 235/639 frames from video (33).avi
# Processed 240/639 frames from video (33).avi
# Processed 245/639 frames from video (33).avi
# Processed 250/639 frames from video (33).avi
# Processed 255/639 frames from video (33).avi
# Processed 260/639 frames from video (33).avi
# Processed 265/639 frames from video (33).avi
# Processed 270/639 frames from video (33).avi
# Processed 275/639 frames from video (33).avi
# Processed 280/639 frames from video (33).avi
# Processed 285/639 frames from video (33).avi
# Processed 290/639 frames from video (33).avi
# Processed 295/639 frames from video (33).avi
# Processed 300/639 frames from video (33).avi
# Processed 305/639 frames from video (33).avi
# Processed 310/639 frames from video (33).avi
# Processed 315/639 frames from video (33).avi
# Processed 320/639 frames from video (33).avi
# Processed 325/639 frames from video (33).avi
# Processed 330/639 frames from video (33).avi
# Processed 335/639 frames from video (33).avi
# Processed 340/639 frames from video (33).avi
# Processed 345/639 frames from video (33).avi
# Processed 350/639 frames from video (33).avi
# Processed 355/639 frames from video (33).avi
# Processed 360/639 frames from video (33).avi
# Processed 365/639 frames from video (33).avi
# Processed 370/639 frames from video (33).avi
# Processed 375/639 frames from video (33).avi
# Processed 380/639 frames from video (33).avi
# Processed 385/639 frames from video (33).avi
# Processed 390/639 frames from video (33).avi
# Processed 395/639 frames from video (33).avi
# Processed 400/639 frames from video (33).avi
# Processed 405/639 frames from video (33).avi
# Processed 410/639 frames from video (33).avi
# Processed 415/639 frames from video (33).avi
# Processed 420/639 frames from video (33).avi
# Processed 425/639 frames from video (33).avi
# Processed 430/639 frames from video (33).avi
# Processed 435/639 frames from video (33).avi
# Processed 440/639 frames from video (33).avi
# Processed 445/639 frames from video (33).avi
# Processed 450/639 frames from video (33).avi
# Processed 455/639 frames from video (33).avi
# Processed 460/639 frames from video (33).avi
# Processed 465/639 frames from video (33).avi
# Processed 470/639 frames from video (33).avi
# Processed 475/639 frames from video (33).avi
# Processed 480/639 frames from video (33).avi
# Processed 485/639 frames from video (33).avi
# Processed 490/639 frames from video (33).avi
# Processed 495/639 frames from video (33).avi
# Processed 500/639 frames from video (33).avi
# Processed 505/639 frames from video (33).avi
# Processed 510/639 frames from video (33).avi
# Processed 515/639 frames from video (33).avi
# Processed 520/639 frames from video (33).avi
# Processed 525/639 frames from video (33).avi
# Processed 530/639 frames from video (33).avi
# Processed 535/639 frames from video (33).avi
# Processed 540/639 frames from video (33).avi
# Processed 545/639 frames from video (33).avi
# Processed 550/639 frames from video (33).avi
# Processed 555/639 frames from video (33).avi
# Processed 560/639 frames from video (33).avi
# Processed 565/639 frames from video (33).avi
# Processed 570/639 frames from video (33).avi
# Processed 575/639 frames from video (33).avi
# Processed 580/639 frames from video (33).avi
# Processed 585/639 frames from video (33).avi
# Processed 590/639 frames from video (33).avi
# Processed 595/639 frames from video (33).avi
# Processed 600/639 frames from video (33).avi
# Processed 605/639 frames from video (33).avi
# Processed 610/639 frames from video (33).avi
# Processed 615/639 frames from video (33).avi
# Processed 620/639 frames from video (33).avi
# Processed 625/639 frames from video (33).avi
# Processed 630/639 frames from video (33).avi
# Processed 635/639 frames from video (33).avi
# Video prediction: 1 (True label: 0)
# Processed 639 frames with avg processing time: 0.0332 seconds
#
# Confusion Matrix:
# True Positives (TP): 61
# True Negatives (TN): 46
# False Positives (FP): 14
# False Negatives (FN): 69
#
# Performance Metrics:
# Accuracy: 56.32%
# Precision: 81.33%
# Recall (Sensitivity): 46.92%
# Specificity: 76.67%
# F1 Score: 59.51%
#
# Comparison with Paper's Metrics:
#                   | Our Method | Paper's Method
# ------------------|------------|---------------
# Accuracy          | 56.32%     | 96.15%
# Precision         | 81.33%     | 97.00%
# Recall            | 46.92%     | 97.98%
# Specificity       | 76.67%     | 90.32%
# F1 Score          | 59.51%     | 97.48%
#
# Processing Statistics:
# Total videos processed: 190
# Total frames processed: 49878
# Average processing time per frame: 0.0826 seconds
# Average FPS: 12.11
